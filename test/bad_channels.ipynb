# %%
import helper
import mne
import scipy.io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
pd.options.display.html.table_schema = True
pd.options.display.max_rows = None
from pathlib import Path, PurePath

# %matplotlib
plt.rcParams.update({'font.size': 14})
# Out:
# Using matplotlib backend: Qt5Agg

# %%
subjects =['AnRa', 'AnRi', 'ArLa', 'BeFe','DiAs', 'FaWa','JuRo', 'NeLa', 'SoGi']
task = ['rest_baseline', 'stimuli']

# %%
# Parameters 

# Subject and task
subject = subjects[0]
task = task[0]
run = '2'
subject_id = '00'
proc = 'raw'
suffix = '_lnrmv.set'
montage = 'preproc'


# High frequency bands 
l_freq = 60
nband = 6 
band_size = 20 

# Epoch parameter

tmin = -0.5 # Prestimulus
tmax = 1.75 # Poststimulus

# Saving paramerters 

save2 = Path('~','projects','CIFAR','data_fun').expanduser()
task_save = 'stimuli'
suffix_place = '_epoch_place.mat'
suffix_face = '_epoch_face.mat'

# %%
raw, dfelec = helper.import_data(task=task, proc=proc, montage=montage, run=run, subject=subject, subject_id=subject_id, suffix=suffix)
raw.plot(duration =150, n_channels=30, scalings=2e-4, color='b')
# Out:
# /home/guime/projects/CIFAR/new_code/test/helper.py:26: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = mne.io.read_raw_eeglab(fpath, preload=load)
# /home/guime/projects/CIFAR/new_code/test/helper.py:26: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(fpath, preload=load)

# %%
raw.plot(duration=100, n_channels=30, scalings=4e-4, color='b')

# %%
raw.info
# Out:
# <Info | 17 non-empty fields
#     bads : list | F7, F3, T3, T5, P3
#     ch_names : list | TRIG, Grid1, Grid2, Grid3, Grid4, Grid5, Grid6, Grid7, ...
#     chs : list | 128 items (EEG: 128)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     dig : Digitization | 128 items (128 EEG)
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 250.00000799968518 Hz
#     meas_date : NoneType | unspecified
#     nchan : int | 128
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 500.00001599937036 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     device_info : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     helium_info : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     utc_offset : NoneType
#     xplotter_layout : NoneType
# >
